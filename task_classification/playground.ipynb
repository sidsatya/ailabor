# %%
import pandas as pd
from gpt_classification import read_system_prompt, process_dataframe

# %%
onet_data = pd.read_csv("../data/task_statements.csv")

# %%
onet_data
# Out:
#       O*NET-SOC Code                              Title  Task ID  \
# 0         11-1011.00                   Chief Executives     8823
# 1         11-1011.00                   Chief Executives     8831
# 2         11-1011.00                   Chief Executives     8825
# 3         11-1011.00                   Chief Executives     8826
# 4         11-1011.00                   Chief Executives     8827
# ...              ...                                ...      ...
# 19525     53-7121.00  Tank Car, Truck, and Ship Loaders    12806
# 19526     53-7121.00  Tank Car, Truck, and Ship Loaders    12807
# 19527     53-7121.00  Tank Car, Truck, and Ship Loaders    12808
# 19528     53-7121.00  Tank Car, Truck, and Ship Loaders    12809
# 19529     53-7121.00  Tank Car, Truck, and Ship Loaders    12810
#
#                                                     Task     Task Type  \
# 0      Direct or coordinate an organization's financi...          Core
# ...

# %%
# Read system prompt
system_prompt = read_system_prompt('prompts/system_level_prompt.txt')

# Process the DataFrame
classified_data = process_dataframe(onet_data, system_prompt)

# Display results
classified_data.head()
# Out:
# None
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[8], line 5
#       2 system_prompt = read_system_prompt('prompts/system_level_prompt.txt')
#       4 # Process the DataFrame
# ----> 5 classified_data = process_dataframe(onet_data, system_prompt)
#       7 # Display results
#       8 classified_data.head()
#
# File ~/dev/ailabor/task_classification/gpt_classification.py:25, in process_dataframe(df, system_prompt)
#      23 # Initialize OpenAI client
#      24 print(os.getenv("OPENAI_API_KEY"))
# ---> 25 client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))  # Uses OPENAI_API_KEY from environment variables
#      27 # Create a copy to avoid modifying the original
#      28 df_processed = df.copy()
#
# ...
