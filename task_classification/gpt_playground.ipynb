# %%
import pandas as pd
from gpt_classification import read_system_prompt, process_dataframe

# %%
onet_data = pd.read_csv("../data/task_statements.csv")

# %%
onet_data.iloc[:10,:]
# Out:
#   O*NET-SOC Code             Title  Task ID  \
# 0     11-1011.00  Chief Executives     8823
# 1     11-1011.00  Chief Executives     8831
# 2     11-1011.00  Chief Executives     8825
# 3     11-1011.00  Chief Executives     8826
# 4     11-1011.00  Chief Executives     8827
# 5     11-1011.00  Chief Executives     8824
# 6     11-1011.00  Chief Executives     8836
# 7     11-1011.00  Chief Executives     8832
# 8     11-1011.00  Chief Executives     8835
# 9     11-1011.00  Chief Executives     8833
#
#                                                 Task Task Type  \
# 0  Direct or coordinate an organization's financi...      Core
# 1  Appoint department heads or managers and assig...      Core
# 2  Analyze operations to evaluate performance of ...      Core
# 3  Direct, plan, or implement policies, objective...      Core
# 4  Prepare budgets for approval, including those ...      Core
# 5  Confer with board members, organization offici...      Core
# 6  Implement corrective action plans to solve org...      Core
# 7  Direct human resources activities, including t...      Core
# 8  Establish departmental responsibilities and co...      Core
# 9  Preside over or serve on boards of directors, ...      Core
#
#    Incumbents Responding     Date Domain Source
# 0                   87.0  07/2014     Incumbent
# 1                   87.0  07/2014     Incumbent
# 2                   87.0  07/2014     Incumbent
# 3                   87.0  07/2014     Incumbent
# 4                   87.0  07/2014     Incumbent
# 5                   87.0  07/2014     Incumbent
# 6                   87.0  07/2014     Incumbent
# 7                   86.0  07/2014     Incumbent
# 8                   86.0  07/2014     Incumbent
# 9                   87.0  07/2014     Incumbent

# %%
# Read system prompt
system_prompt = read_system_prompt('prompts/system_level_prompt.txt')

# Process the DataFrame
classified_data = process_dataframe(onet_data.iloc[:10,:], system_prompt)

# Display results
classified_data.head()
# Out:
# Processing batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved batch 1 to data/intermediate_results/classified_tasks_batch_1_20250401_225212.csv
# Processing batches: 100%|██████████| 1/1 [00:03<00:00,  3.69s/it]
# Saved final results to data/classified_tasks_final_20250401_225213.csv
#                                                 Task gpt_label
# 0  Appoint department heads or managers and assig...      DMNR
# 1  Analyze operations to evaluate performance of ...      DMNR
# 2  Direct or coordinate an organization's financi...      DMNR
# 3  Direct, plan, or implement policies, objective...      DMNR
# 4  Confer with board members, organization offici...       INR
